# %% [markdown]
# # Stock Prediction using ARIMA, SARIMA, HOLTS WINTER AND LSTM

# %% [markdown]
# DATASET

# %% [markdown]
# ![LSTM%20-%20dataset.png](attachment:LSTM%20-%20dataset.png)

# %% [markdown]
# Checked for Data types

# %% [markdown]
# ![LSTM%20-%20INFO.png](attachment:LSTM%20-%20INFO.png)

# %% [markdown]
# Date was in object, so converted it into datetime format and set data as index

# %% [markdown]
# ## Univariate - Forecasting

# %% [markdown]
# Selected one column "Close" as a univariate and visualized

# %% [markdown]
# ![LSTM%20%28Before%20M%29.png](attachment:LSTM%20%28Before%20M%29.png)

# %% [markdown]
# Since Forecasting data should not have null values and the Frequency of the data must be equal,so performed resampling

# %% [markdown]
# ![time%20series%20Rules.png](attachment:time%20series%20Rules.png)

# %% [markdown]
# ![timeseries%20Rules%201.png](attachment:timeseries%20Rules%201.png)

# %% [markdown]
# Data was Resampled into month (Rule = M)

# %% [markdown]
# ![LSTM%20%28M%29.png](attachment:LSTM%20%28M%29.png)

# %% [markdown]
# Components of forecasting - trend, seasonality, Noise were visualized

# %% [markdown]
# ![LSTM%20-%20Seasonal%20decompose.png](attachment:LSTM%20-%20Seasonal%20decompose.png)

# %% [markdown]
# ## ARIMA, SARIMA AND HOLTS WINTER

# %% [markdown]
# Checked for stationarity using Dickey fuller test
#
#
# Dataset was not Stationary---differencing was done to make stationary

# %% [markdown]
# ![differencing.png](attachment:differencing.png)

# %% [markdown]
# ACF AND PACF plots were used to determine p and q values

# %% [markdown]
# PACF Plot gives value of P, ACF Plot gives value of q and differencing give value of d

# %% [markdown]
# ![acf.png](attachment:acf.png)

# %% [markdown]
# ![pacf.png](attachment:pacf.png)

# %% [markdown]
# Data was splitted into Train and test, performed ARIMA, Sarima and Holt winter model. Checked for residuals and ploted

# %% [markdown]
# ![result%20-%20ar,%20sar,%20holt.png](attachment:result%20-%20ar,%20sar,%20holt.png)

# %% [markdown]
# Since Datasets are seasonal SARIMA AND Holtwinter performed good rather than ARIMA

# %% [markdown]
# # LSTM

# %% [markdown]
# UNIVARIATE

# %% [markdown]
# For LSTM, Scaling is the important step. Then dataset is split into Train and test. XTrain and Ytrain was created and LSTM was performed with input layers, dense layers.

# %% [markdown]
# LSTM Model was fitted and predicted. then Inverse scaling must be done to get the original values

# %% [markdown]
# ![legend.png](attachment:legend.png)

# %% [markdown]
# ![lstm-%20result.png](attachment:lstm-%20result.png)

# %% [markdown]
# MULTIVARIATE

# %% [markdown]
# The below metioned columns were taken for multivariate analysis

# %% [markdown]
# ![lstm%20-%20multivariate.png](attachment:lstm%20-%20multivariate.png)

# %% [markdown]
# Dataset was scaled, Splited into Train and test. LSTM Model was fited and forecasted

# %% [markdown]
# ![lstm%20multi%20result.png](attachment:lstm%20multi%20result.png)
